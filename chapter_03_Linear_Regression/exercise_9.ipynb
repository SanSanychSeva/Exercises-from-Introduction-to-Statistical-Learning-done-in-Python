# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Text-of-exercise-9-chapter-3-ISLRv2-book" data-toc-modified-id="Text-of-exercise-9-chapter-3-ISLRv2-book-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Text of exercise 9 chapter 3 ISLRv2 book</a></span></li><li><span><a href="#Data-reading-and-preprocessing" data-toc-modified-id="Data-reading-and-preprocessing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data reading and preprocessing</a></span></li><li><span><a href="#item-a" data-toc-modified-id="item-a-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>item a</a></span></li><li><span><a href="#item-b" data-toc-modified-id="item-b-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>item b</a></span></li><li><span><a href="#item-c:-Multiple-Linear-Regression-of-mpg" data-toc-modified-id="item-c:-Multiple-Linear-Regression-of-mpg-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>item c: Multiple Linear Regression of <code>mpg</code></a></span><ul class="toc-item"><li><span><a href="#precision-of-model-on-training-data" data-toc-modified-id="precision-of-model-on-training-data-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>precision of model on training data</a></span></li><li><span><a href="#t_statistics-for-each-parameter" data-toc-modified-id="t_statistics-for-each-parameter-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>t_statistics for each parameter</a></span></li></ul></li><li><span><a href="#item-d:-Outliers" data-toc-modified-id="item-d:-Outliers-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>item d: Outliers</a></span><ul class="toc-item"><li><span><a href="#Conclusions:" data-toc-modified-id="Conclusions:-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Conclusions:</a></span></li><li><span><a href="#yet-let's-play-with-dropping-outliers:" data-toc-modified-id="yet-let's-play-with-dropping-outliers:-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>yet let's play with dropping outliers:</a></span><ul class="toc-item"><li><span><a href="#if-we-drop-only-high-leverage-outliers:" data-toc-modified-id="if-we-drop-only-high-leverage-outliers:-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>if we drop only high leverage outliers:</a></span></li><li><span><a href="#if-we-drop-only-high-residual-outliers:" data-toc-modified-id="if-we-drop-only-high-residual-outliers:-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>if we drop only high residual outliers:</a></span></li><li><span><a href="#Conclusion:-so,-high-leverage-outliers-are-no-problem-if-their-residual-is-small!" data-toc-modified-id="Conclusion:-so,-high-leverage-outliers-are-no-problem-if-their-residual-is-small!-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Conclusion: so, high leverage outliers are no problem if their residual is small!</a></span></li><li><span><a href="#hense-let's-try-optimised-outliers-drop-criteria:" data-toc-modified-id="hense-let's-try-optimised-outliers-drop-criteria:-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>hense let's try optimised outliers-drop criteria:</a></span></li><li><span><a href="#Summary-table-for-all-variants-of-dropping-outliers-and-its-effects" data-toc-modified-id="Summary-table-for-all-variants-of-dropping-outliers-and-its-effects-6.2.5"><span class="toc-item-num">6.2.5&nbsp;&nbsp;</span>Summary table for all variants of dropping outliers and its effects</a></span></li></ul></li></ul></li><li><span><a href="#item-e:-Small-nonelinearity-of-f(X)" data-toc-modified-id="item-e:-Small-nonelinearity-of-f(X)-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>item e: Small nonelinearity of f(X)</a></span><ul class="toc-item"><li><span><a href="#Conclusions:" data-toc-modified-id="Conclusions:-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Conclusions:</a></span></li></ul></li><li><span><a href="#item-f:-Using-none-linear-trasformation-of-parameter-values" data-toc-modified-id="item-f:-Using-none-linear-trasformation-of-parameter-values-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>item f: Using none linear trasformation of parameter values</a></span></li></ul></div>

# %% [markdown]
# # Text of exercise 9 chapter 3 ISLRv2 book
#
# This question involves the use of multiple linear regression on the Auto data set.
#
# (a) Produce a scatterplot matrix which includes all of the variables
# in the data set.
#
# (b) Compute the matrix of correlations between the variables using
# the function cor(). You will need to exclude the name variable, which is qualitative.
#
# (c) Use the lm() function to perform a multiple linear regression
# with mpg as the response and all other variables except name as
# the predictors. Use the summary() function to print the results.
# Comment on the output. For instance:
#
# i. Is there a relationship between the predictors and the response?
#
# ii. Which predictors appear to have a statistically significant
# relationship to the response?
#
# iii. What does the coefficient for the year variable suggest?
#
# (d) Use the plot() function to produce diagnostic plots of the linear
# regression fit. Comment on any problems you see with the fit.
# Do the residual plots suggest any unusually large outliers? Does
# the leverage plot identify any observations with unusually high
# leverage?
#
#
# (e) Use the * and : symbols to fit linear regression models with
# interaction effects. Do any interactions appear to be statistically
# significant?
#
# (f) Try a few different transformations of the variables, such as
# log(X), √X, X2. Comment on your findings.
#
# \*) **ISLRv2** stands for: **An Introduction to Statistical Learning book by Gareth James, Daniela Witten, Trevor Hastie, Robert Tibshirani**

# %%
import math
import pandas as pd
import numpy as np
import scipy.stats as statmath 
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data reading and preprocessing

# %%
df = pd.read_csv('datasets/Auto.csv')
df.info()
df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# ...

# %%
df = df[df['horsepower'].map(str.isdecimal)]
df['horsepower'] = pd.to_numeric(df['horsepower'])
df = df.reset_index(drop=True)
save_this = df['mpg'].mean() # will be needed in the very end - not to change too much of code, disregard this line now
df.info()
df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
#  8   name          392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# # item a

# %%
sns.pairplot(df.drop(columns='name'))
plt.show()

# %% [markdown]
# # item b

# %%
round( df.drop(columns='name').corr(), 3)
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# mpg           1.000     -0.778        -0.805      -0.778  -0.832
# cylinders    -0.778      1.000         0.951       0.843   0.898
# displacement -0.805      0.951         1.000       0.897   0.933
# horsepower   -0.778      0.843         0.897       1.000   0.865
# weight       -0.832      0.898         0.933       0.865   1.000
# acceleration  0.423     -0.505        -0.544      -0.689  -0.417
# year          0.581     -0.346        -0.370      -0.416  -0.309
# origin        0.565     -0.569        -0.615      -0.455  -0.585
#
#               acceleration   year  origin
# mpg                  0.423  0.581   0.565
# cylinders           -0.505 -0.346  -0.569
# displacement        -0.544 -0.370  -0.615
# horsepower          -0.689 -0.416  -0.455
# weight              -0.417 -0.309  -0.585
# acceleration         1.000  0.290   0.213
# year                 0.290  1.000   0.182
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(abs(df.drop(columns='name').corr()), vmin=0, vmax=1, annot=True, fmt='.3g', linewidths=1)
plt.show()

# %% [markdown]
# # item c: Multiple Linear Regression of `mpg`

# %%
X = np.array(df.drop(columns=['mpg','name']) )
Y = np.array(df['mpg'])

MLR_model_obj = linear_model.LinearRegression() # creating model object
MLR_model_obj.fit(X,Y)

def mpg_f(X_test): return MLR_model_obj.predict(X_test)

# %% [markdown]
# ## precision of model on training data

# %%
print('\nMean squared error:', MSE_0 := mean_squared_error(Y, MLR_model_obj.predict(X)), '\n' )

print('Coefficient of determination - R^2 statistics (variant 1):', R2_0 := MLR_model_obj.score(X,Y) )
print('Coefficient of determination - R^2 statistics (variant 2):', r2_score(Y, MLR_model_obj.predict(X)) )
# Out:
# Mean squared error: 10.847480945000454
#
# Coefficient of determination - R^2 statistics (variant 1): 0.8214780764810597
# Coefficient of determination - R^2 statistics (variant 2): 0.8214780764810597

# %% [markdown]
# ## t_statistics for each parameter
# alas, there is no params like t-statistics (or f-) in the library model - so we might go for some bootstrapping:

# %%
def random_one_half_df(df, rng = np.random.default_rng()):  # random sampling for 1/2 rows from df
    n = len(df)//2
    rows_list = []
    while len(rows_list) < n:
        candidate = rng.integers(len(df))
        if candidate not in rows_list:  rows_list.append(candidate)
    return df.loc[rows_list]

sample_MLR_model_obj = linear_model.LinearRegression() # creating model object
beta = []                                              # here we save MLR parameters for random samples

bootstrap_n = 2*len(df)                                # the more - the better, yet it is getting long
for i in range(bootstrap_n):                     
    sample_df = random_one_half_df(df)
    x = np.array(sample_df.drop(columns=['mpg','name']))
    y = np.array(sample_df['mpg'])
    sample_MLR_model_obj.fit(x,y)
    beta.append([sample_MLR_model_obj.intercept_] + list(sample_MLR_model_obj.coef_))
    
MLR_stat_df_samples = pd.DataFrame(
    beta,
    columns = ['intercept']+list(df.drop(columns=['mpg','name']).columns)
)

# %%
print("\nLet's compare coefficients between model and bootstrapping-mean:")

confidence_df = MLR_stat_df_samples.describe().iloc[[0,1,2]].T

confidence_df['model'] = [ MLR_model_obj.intercept_] + list(MLR_model_obj.coef_)

confidence_df['delta_mean_to_model'] = confidence_df['mean'] - confidence_df['model']

confidence_df['delta_vs_std/sqroot(N)'] = (confidence_df['delta_mean_to_model'] / confidence_df['std'] * 
                                           math.sqrt(len(df)) ).map(abs).map(lambda x: round(x,1))

confidence_df['t_stat_v1'] = confidence_df['mean'] / (confidence_df['std'] / confidence_df['count'].map(math.sqrt) )

confidence_df['p_value_v1'] = confidence_df['t_stat_v1'].map(lambda x: statmath.t.sf(abs(x), len(df)//2 - 1) *2)

confidence_df['(t_stat, p_value)_v2'] = [ statmath.ttest_1samp(list(MLR_stat_df_samples[bt]),0) 
                                          for bt in list(confidence_df.index) ]

round(confidence_df,5)
# Out:
# Let's compare coefficients between model and bootstrapping-mean:
#               count      mean      std     model  delta_mean_to_model  \
# intercept     784.0 -17.16346  4.66113 -17.21843              0.05497
# cylinders     784.0  -0.48177  0.31891  -0.49338              0.01161
# displacement  784.0   0.02032  0.00837   0.01990              0.00043
# horsepower    784.0  -0.01730  0.01439  -0.01695             -0.00035
# weight        784.0  -0.00655  0.00079  -0.00647             -0.00007
# acceleration  784.0   0.08101  0.13180   0.08058              0.00043
# year          784.0   0.75143  0.04956   0.75077              0.00065
# origin        784.0   1.42659  0.28244   1.42614              0.00045
#
#               delta_vs_std/sqroot(N)  t_stat_v1  p_value_v1  \
# intercept                        0.2 -103.10316         0.0
# cylinders                        0.7  -42.29860         0.0
# displacement                     1.0   67.95022         0.0
# ...

# %% [markdown]
# # item d: Outliers
# we shall use the leverage-residual studentised coords to identify ourliers:
# * `horisontal axis (leverage):` $Y_{predicted}\ -\ \bar{Y}_{predicted}$ / studentized  (actually for linear prediction $\bar{Y}_{predicted}\ =\ \bar{Y}_{actual}$)
# * `vertical axis   (residual):` $Y_{actual}\ -\ Y_{predicted}$ / studentized

# %%
# adding predicted values to main dataframe
df['mpg_pred'] = MLR_model_obj.predict(X)

# %%
print('check that mean value of average predicted value is equal to the mean value: relative_delta=', 
      (df['mpg_pred'].mean() - df['mpg'].mean())/df['mpg'].mean())
# Out:
# check that mean value of average predicted value is equal to the mean value: relative_delta= 1.0606961673226023e-15

# %%
# adding horisontal coord for outliers analyses to main dataframe
df['fitted_value_studentised'] = df['mpg_pred'] - df['mpg_pred'].mean()
df['fitted_value_studentised'] = df['fitted_value_studentised'] / df['fitted_value_studentised'].std()

# %%
# adding vertical coord for outliers analyses to main dataframe
df['residual_value_studentized'] = df['mpg'] - df['mpg_pred']
df['residual_value_studentized'] = df['residual_value_studentized'] / df['residual_value_studentized'].std()

# %%
show_df = df.sort_values('fitted_value_studentised')
show_df['smooth_fit_residuals'] = show_df['residual_value_studentized'].rolling(3).mean(
                                                                      ).rolling(5).mean(
                                                                      ).rolling(7).mean(
                                                                      ).rolling(11).mean(
                                                                      ).rolling(13).mean()

# %%
plt.figure(figsize=(12,7))

sns.scatterplot(data=show_df, x='fitted_value_studentised', y='residual_value_studentized', marker='x')
sns.lineplot(data=show_df, x='fitted_value_studentised', y='smooth_fit_residuals', color='red', 
             label='smooth fit to residuals')
plt.axhline(y=0, color='black', label='0 - predicted mpg value level')

plt.xlim(-3,3)
plt.ylim(-4,4)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Conclusions:
# 1. Different swaps for positive and negative residuals is caused by nonelinear shape of the true f(X):
#  * in the very middle of distibution prediction is above actual mpg (|leverage| < 1 std),
#  * on the boundary of distribution prediction is less then actual (|leverage| > 1 std)
# 3. There are no big outliers worth of deleting, except maybe right top corner of the distribution.
#
# ## yet let's play with dropping outliers:

# %%
X_good = np.array(df.query('abs(residual_value_studentized) < 2.5 & abs(fitted_value_studentised) < 2').drop(
    columns=['mpg','name','residual_value_studentized','fitted_value_studentised']) )
Y_good = np.array(df.query('abs(residual_value_studentized) < 2.5 & abs(fitted_value_studentised) < 2')['mpg'])

good_MLR_model_obj = linear_model.LinearRegression() # creating model object
good_MLR_model_obj.fit(X_good,Y_good)

print('\nHAVING DROPPED',
      N_3 := len(df)-len(df.query('abs(residual_value_studentized) < 2.5 & abs(fitted_value_studentised) < 2')),
      'OUTLIERS OUT OF', len(df),'WE HAVE SOME IMPROVEMENT IN PREDICTION ON TRAINING DATA:')
print('\nMean squared error:', MSE_3 := mean_squared_error(Y_good, good_MLR_model_obj.predict(X_good)), '\n' )

print('Coefficient of determination - R^2 statistics (variant 1):', R2_3 := good_MLR_model_obj.score(X_good,Y_good) )
print('Coefficient of determination - R^2 statistics (variant 2):', r2_score(Y_good, good_MLR_model_obj.predict(X_good)) )
# Out:
# HAVING DROPPED 21 OUTLIERS OUT OF 392 WE HAVE SOME IMPROVEMENT IN PREDICTION ON TRAINING DATA:
#
# Mean squared error: 7.618042370131591
#
# Coefficient of determination - R^2 statistics (variant 1): 0.8509089393047371
# Coefficient of determination - R^2 statistics (variant 2): 0.8509089393047371

# %% [markdown]
# ### if we drop only high leverage outliers:

# %%
X_good = np.array(df.query('abs(fitted_value_studentised) < 2').drop(
    columns=['mpg','name','residual_value_studentized','fitted_value_studentised']) )
Y_good = np.array(df.query('abs(fitted_value_studentised) < 2')['mpg'])

good_MLR_model_obj = linear_model.LinearRegression() # creating model object
good_MLR_model_obj.fit(X_good,Y_good)

print('\nHAVING DROPPED', N_1 := len(df)-len(df.query('abs(fitted_value_studentised) < 2')),'OUTLIERS OUT OF',
      len(df),'WE SHOULD INFLUENCE MAINLY R^2 STATISTICS:')
print('\nMean squared error:', MSE_1 := mean_squared_error(Y_good, good_MLR_model_obj.predict(X_good)), '\n' )

print('Coefficient of determination - R^2 statistics (variant 1):', R2_1 := good_MLR_model_obj.score(X_good,Y_good) )
print('Coefficient of determination - R^2 statistics (variant 2):', r2_score(Y_good, good_MLR_model_obj.predict(X_good)) )
# Out:
# HAVING DROPPED 10 OUTLIERS OUT OF 392 WE SHOULD INFLUENCE MAINLY R^2 STATISTICS:
#
# Mean squared error: 10.712665539247888
#
# Coefficient of determination - R^2 statistics (variant 1): 0.8164013359551232
# Coefficient of determination - R^2 statistics (variant 2): 0.8164013359551232

# %% [markdown]
# ### if we drop only high residual outliers:

# %%
X_good = np.array(df.query('abs(residual_value_studentized) < 2.5').drop(
    columns=['mpg','name','residual_value_studentized','fitted_value_studentised']) )
Y_good = np.array(df.query('abs(residual_value_studentized) < 2.5')['mpg'])

good_MLR_model_obj = linear_model.LinearRegression() # creating model object
good_MLR_model_obj.fit(X_good,Y_good)

print('\nHAVING DROPPED', N_2 := len(df)-len(df.query('abs(residual_value_studentized) < 2.5')),'OUTLIERS OUT OF',
      len(df),'WE SHOULD MAINLY IMPROVE MSE:')
print('\nMean squared error:', MSE_2 := mean_squared_error(Y_good, good_MLR_model_obj.predict(X_good)), '\n' )

print('Coefficient of determination - R^2 statistics (variant 1):', R2_2 := good_MLR_model_obj.score(X_good,Y_good) )
print('Coefficient of determination - R^2 statistics (variant 2):', r2_score(Y_good, good_MLR_model_obj.predict(X_good)) )
# Out:
# HAVING DROPPED 11 OUTLIERS OUT OF 392 WE SHOULD MAINLY IMPROVE MSE:
#
# Mean squared error: 7.71612735537278
#
# Coefficient of determination - R^2 statistics (variant 1): 0.8557699144068696
# Coefficient of determination - R^2 statistics (variant 2): 0.8557699144068696

# %% [markdown]
# ### Conclusion: so, high leverage outliers are no problem if their residual is small!
#
# ### hense let's try optimised outliers-drop criteria:

# %%
cut = 8 # tuning threshold level

X_good = np.array(df.query(
    'residual_value_studentized*residual_value_studentized+fitted_value_studentised*fitted_value_studentised < @cut'
).drop(
    columns=['mpg','name','residual_value_studentized','fitted_value_studentised']) )
Y_good = np.array(df.query(
    'residual_value_studentized*residual_value_studentized+fitted_value_studentised*fitted_value_studentised < @cut'
)['mpg'])

good_MLR_model_obj = linear_model.LinearRegression() # creating model object
good_MLR_model_obj.fit(X_good,Y_good)

print('\nHAVING DROPPED', N_4 := len(df)-len(df.query(
      'residual_value_studentized*residual_value_studentized+fitted_value_studentised*fitted_value_studentised < @cut'
      )),'OUTLIERS OUT OF',
      len(df),'WE DO NOT HAVE YET BIGGEST IMPROVEMENT IN PREDICTION ON TRAINING DATA:')
print('\nMean squared error:', MSE_4 := mean_squared_error(Y_good, good_MLR_model_obj.predict(X_good)), '\n' )

print('Coefficient of determination - R^2 statistics (variant 1):', R2_4 := good_MLR_model_obj.score(X_good,Y_good) )
print('Coefficient of determination - R^2 statistics (variant 2):', r2_score(Y_good, good_MLR_model_obj.predict(X_good)) )
# Out:
# HAVING DROPPED 11 OUTLIERS OUT OF 392 WE DO NOT HAVE YET BIGGEST IMPROVEMENT IN PREDICTION ON TRAINING DATA:
#
# Mean squared error: 7.804620298209387
#
# Coefficient of determination - R^2 statistics (variant 1): 0.8534193132619033
# Coefficient of determination - R^2 statistics (variant 2): 0.8534193132619033

# %% [markdown]
# ### Summary table for all variants of dropping outliers and its effects

# %%
round(pd.DataFrame({
    'initial MLR precision' : [MSE_0, R2_0, 0],
    'MLR precision drop high leverage' : [MSE_1, R2_1, N_1],
    'MLR precision drop high residual' : [MSE_2, R2_2, N_2],
    'MLR precision drop all outliers' : [MSE_3, R2_3, N_3],
    'MLR precision at optimal drop' : [MSE_4, R2_4, N_4],
}, index=['MSE', 'R^2 st','N drop']), 3)
# Out:
#         initial MLR precision  MLR precision drop high leverage  \
# MSE                    10.847                            10.713
# R^2 st                  0.821                             0.816
# N drop                  0.000                            10.000
#
#         MLR precision drop high residual  MLR precision drop all outliers  \
# MSE                                7.716                            7.618
# R^2 st                             0.856                            0.851
# N drop                            11.000                           21.000
#
#         MLR precision at optimal drop
# MSE                             7.805
# R^2 st                          0.853
# N drop                         11.000

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(data=df.query('abs(residual_value_studentized) >= 2.5'), 
                x='fitted_value_studentised', y='residual_value_studentized', color='red', label=str(
                len(df.query('abs(residual_value_studentized) >= 2.5')))+' dropped outliers')
sns.scatterplot(data=df.query('abs(residual_value_studentized) < 2.5'), 
                x='fitted_value_studentised', y='residual_value_studentized', marker='x')

plt.axhline(y=0, color='black', label='0 - predicted mpg value level')

plt.xlim(-3,3)
plt.ylim(-4,4)
plt.title('visualizing the optimally dropped outliers - outside filled aerea')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # item e: Small nonelinearity of f(X)
# We need to add quadratic terms, but there are plenty of them!

# %%
df = pd.read_csv('datasets/Auto.csv')
df = df[df['horsepower'].map(str.isdecimal)]
df['horsepower'] = pd.to_numeric(df['horsepower'])
df = df.reset_index(drop=True).drop(columns='name')
df.info()
df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 24.6 KB
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
#
#    origin
# 0       1
# 1       1

# %%
clist = list(df.columns)
n = len(clist)

for i in range(1,n):
    for j in range(i,n):
        c1 = clist[i]
        c2 = clist[j]
        df[c1+'_'+c2] = df[c1]*df[c2]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   mpg                        392 non-null    float64
#  1   cylinders                  392 non-null    int64
#  2   displacement               392 non-null    float64
#  3   horsepower                 392 non-null    int64
#  4   weight                     392 non-null    int64
#  5   acceleration               392 non-null    float64
#  6   year                       392 non-null    int64
#  7   origin                     392 non-null    int64
#  8   cylinders_cylinders        392 non-null    int64
#  9   cylinders_displacement     392 non-null    float64
#  10  cylinders_horsepower       392 non-null    int64
#  11  cylinders_weight           392 non-null    int64
#  12  cylinders_acceleration     392 non-null    float64
# ...

# %%
quadroX = np.array(df.drop(columns='mpg') )
Y = np.array(df['mpg'])

quadroMR_model_obj = linear_model.LinearRegression() # creating model object
quadroMR_model_obj.fit(quadroX,Y)

print('\nMean squared error:', mean_squared_error(Y, quadroMR_model_obj.predict(quadroX)), '\n' )

print('Coefficient of determination - R^2 statistics (variant 1):', quadroMR_model_obj.score(quadroX,Y) )
print('Coefficient of determination - R^2 statistics (variant 2):', r2_score(Y, quadroMR_model_obj.predict(quadroX)) )
# Out:
# Mean squared error: 6.36097640990333
#
# Coefficient of determination - R^2 statistics (variant 1): 0.8953145204944633
# Coefficient of determination - R^2 statistics (variant 2): 0.8953145204944633

# %%
def random_one_half_df(df, rng = np.random.default_rng()):  # random sampling for 1/2 rows from df
    n = len(df)//2
    rows_list = []
    while len(rows_list) < n:
        candidate = rng.integers(len(df))
        if candidate not in rows_list:  rows_list.append(candidate)
    return df.loc[rows_list]

sample_quadroMR_model_obj = linear_model.LinearRegression() # creating model object
beta = []                                              # here we save quadroMR parameters for random samples

bootstrap_n = 2*len(df)                                # the more - the better, yet it is getting long
for i in range(bootstrap_n):                     
    sample_df = random_one_half_df(df)
    x = np.array(sample_df.drop(columns='mpg'))
    y = np.array(sample_df['mpg'])
    sample_quadroMR_model_obj.fit(x,y)
    beta.append([sample_quadroMR_model_obj.intercept_] + list(sample_quadroMR_model_obj.coef_))
    
quadroMR_stat_df_samples = pd.DataFrame(
    beta,
    columns = ['intercept']+list(df.drop(columns='mpg').columns)
)

# %%
print("\nLet's compare coefficients between model and bootstrapping-mean:")

confidence_df = quadroMR_stat_df_samples.describe().iloc[[0,1,2]].T

confidence_df['model'] = [ quadroMR_model_obj.intercept_] + list(quadroMR_model_obj.coef_)

confidence_df['delta_mean_to_model'] = confidence_df['mean'] - confidence_df['model']

confidence_df['delta_vs_std/sqroot(N)'] = (confidence_df['delta_mean_to_model'] / confidence_df['std'] * 
                                           math.sqrt(len(df)) ).map(abs).map(lambda x: round(x,1))

confidence_df['t_stat_v1'] = confidence_df['mean'] / (confidence_df['std'] / confidence_df['count'].map(math.sqrt) )

confidence_df['p_value_v1'] = confidence_df['t_stat_v1'].map(lambda x: statmath.t.sf(abs(x), len(df)//2 - 1) *2)

confidence_df['(t_stat, p_value)_v2'] = [ statmath.ttest_1samp(list(quadroMR_stat_df_samples[bt]),0) 
                                          for bt in list(confidence_df.index) ]

round(confidence_df.sort_values('t_stat_v1').drop(columns=['delta_mean_to_model','delta_vs_std/sqroot(N)']),5)
# Out:
# Let's compare coefficients between model and bootstrapping-mean:
#                            count       mean        std      model  t_stat_v1  \
# year                       784.0   -7.61615    2.49914   -8.10988  -85.33043
# acceleration               784.0   -7.10104    3.10735   -7.35007  -63.98666
# origin                     784.0  -20.01516    9.28362  -20.80358  -60.36699
# displacement               784.0   -0.51905    0.29849   -0.59029  -48.69031
# cylinders_year             784.0   -0.13511    0.12696   -0.13913  -29.79733
# cylinders_cylinders        784.0   -0.51052    0.48744   -0.51215  -29.32613
# weight_year                784.0   -0.00029    0.00029   -0.00033  -28.09094
# displacement_displacement  784.0   -0.00021    0.00038   -0.00012  -15.35087
# horsepower_horsepower      784.0   -0.00029    0.00061   -0.00026  -13.19504
# horsepower_weight          784.0   -0.00003    0.00006   -0.00003  -12.88973
# ...

# %% [markdown]
# ## Conclusions:
# 1. Adding quadratic interactions has greatly improved the precision of the model - ON TRAINING DATA!
# 2. **Although we have now too many degree of freedom (35) for only 392 samples, so only 11 samples per one degree of freedom - too few, we would need at least 30 for reliable statistics!**  And this can be seen by next item - if we repeat sampling, we get in item 3 as a results the two, three, four and even five lines of insignificant interactions, so p_value are not even stable as for sampling we used half dataset - with 5 independent samples per one degree of freedom!  This was **`the curse of dimensionality`**!
# 3. All quadratic interactions seems statistically significant except the ones with p_value > significance_alpha:

# %%
alpha = 0.01
print('If significance level is taken as',alpha, 'than the only insignificant interactions are between:')
round(confidence_df.query('p_value_v1 > @alpha')[['t_stat_v1','p_value_v1']],5)
# Out:
# If significance level is taken as 0.01 than the only insignificant interactions are between:
#                       t_stat_v1  p_value_v1
# cylinders_horsepower    2.20984     0.02828
# horsepower_origin       2.15914     0.03206
# weight_origin          -1.33094     0.18476

# %% [markdown]
# # item f: Using none linear trasformation of parameter values
# Let's try to predict 1/mpg - as this is expected to be more linear towards horsepower!

# %%
df = pd.read_csv('datasets/Auto.csv')
df = df[df['horsepower'].map(str.isdecimal)]
df['horsepower'] = pd.to_numeric(df['horsepower'])
df['mpg'] = 1 / df['mpg']
df = df.reset_index(drop=True)
df.info()
df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
#  8   name          392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB
#         mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  0.055556          8         307.0         130    3504          12.0    70
# 1  0.066667          8         350.0         165    3693          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# ...

# %%
X = np.array(df.drop(columns=['mpg','name']) )
Y = np.array(df['mpg'])

MLR_model_obj = linear_model.LinearRegression() # creating model object
MLR_model_obj.fit(X,Y)

print('\nMean squared error:', MSE_5 := mean_squared_error(Y, MLR_model_obj.predict(X)), '\n' )

print('Coefficient of determination - R^2 statistics (variant 1):', R2_5 := MLR_model_obj.score(X,Y) )
print('Coefficient of determination - R^2 statistics (variant 2):', r2_score(Y, MLR_model_obj.predict(X)) )
# Out:
# Mean squared error: 3.168999502664599e-05
#
# Coefficient of determination - R^2 statistics (variant 1): 0.8852496099524023
# Coefficient of determination - R^2 statistics (variant 2): 0.8852496099524023

# %% [markdown]
# To be able to compare also by MSE we need to normalize it to mean value (as Y (mpg vs 1/mpg) are now different)

# %%
print('\nPREDICTION PRECISION IS BETTER FOR 1/mpg AS COMPARED TO PREDICTION OF mpg:')

round(pd.DataFrame(
    {
    'relative MLR precision for mpg' : [MSE_0/math.pow(save_this,2), R2_0],
    'relative MLR precision for 1/mpg' : [MSE_5/math.pow(df['mpg'].mean(),2), R2_5]
    }, 
    index=['MSE/mean(Y)^2', 'R^2 statistics']
), 3)
# Out:
# PREDICTION PRECISION IS BETTER FOR 1/mpg AS COMPARED TO PREDICTION OF mpg:
#                 relative MLR precision for mpg  \
# MSE/mean(Y)^2                            0.020
# R^2 statistics                           0.821
#
#                 relative MLR precision for 1/mpg
# MSE/mean(Y)^2                              0.014
# R^2 statistics                             0.885
