# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Text-of-exercise-14-chapter-3-ISLRv2-book" data-toc-modified-id="Text-of-exercise-14-chapter-3-ISLRv2-book-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Text of exercise 14 chapter 3 ISLRv2 book</a></span></li><li><span><a href="#Functions-for-used-statistical-formulas" data-toc-modified-id="Functions-for-used-statistical-formulas-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Functions for used statistical formulas</a></span></li><li><span><a href="#items-a:-data-generation" data-toc-modified-id="items-a:-data-generation-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>items a: data generation</a></span><ul class="toc-item"><li><span><a href="#Conclusions:" data-toc-modified-id="Conclusions:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Conclusions:</a></span></li></ul></li><li><span><a href="#item-b:-correlation-and-plotting-of-data" data-toc-modified-id="item-b:-correlation-and-plotting-of-data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>item b: correlation and plotting of data</a></span><ul class="toc-item"><li><span><a href="#Conclusions:" data-toc-modified-id="Conclusions:-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Conclusions:</a></span></li></ul></li><li><span><a href="#item-c:-multiple-linear-regression-of-Y-onto-X-(MLR):" data-toc-modified-id="item-c:-multiple-linear-regression-of-Y-onto-X-(MLR):-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>item c: multiple linear regression of <code>Y</code> onto <code>X</code> (MLR):</a></span><ul class="toc-item"><li><span><a href="#Hypothesis-checking" data-toc-modified-id="Hypothesis-checking-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Hypothesis checking</a></span><ul class="toc-item"><li><span><a href="#$H_0\,-:\,\,-\beta_i-=-0$" data-toc-modified-id="$H_0\,-:\,\,-\beta_i-=-0$-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>$H_0\, :\,\, \beta_i = 0$</a></span></li><li><span><a href="#$H_0\,-:\,\,-\beta_i-=-\beta_i^{true}$" data-toc-modified-id="$H_0\,-:\,\,-\beta_i-=-\beta_i^{true}$-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>$H_0\, :\,\, \beta_i = \beta_i^{true}$</a></span></li></ul></li><li><span><a href="#Conclusions:" data-toc-modified-id="Conclusions:-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Conclusions:</a></span></li></ul></li><li><span><a href="#item-d:-simple-linear-regression-of-Y-onto-X1-(SLR_x1)" data-toc-modified-id="item-d:-simple-linear-regression-of-Y-onto-X1-(SLR_x1)-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>item d: simple linear regression of <code>Y</code> onto <code>X1</code> (SLR_x1)</a></span><ul class="toc-item"><li><span><a href="#Hypothesis-checking" data-toc-modified-id="Hypothesis-checking-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Hypothesis checking</a></span><ul class="toc-item"><li><span><a href="#$H_0\,-:\,\,-\beta_i-=-0$" data-toc-modified-id="$H_0\,-:\,\,-\beta_i-=-0$-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>$H_0\, :\,\, \beta_i = 0$</a></span></li><li><span><a href="#$H_0\,-:\,\,-\beta_i-=-\beta_i^{true}$" data-toc-modified-id="$H_0\,-:\,\,-\beta_i-=-\beta_i^{true}$-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>$H_0\, :\,\, \beta_i = \beta_i^{true}$</a></span></li></ul></li><li><span><a href="#Conclusions:" data-toc-modified-id="Conclusions:-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Conclusions:</a></span></li></ul></li><li><span><a href="#item-e:-simple-linear-regression-of-Y-onto-X2-(SLR_x2)" data-toc-modified-id="item-e:-simple-linear-regression-of-Y-onto-X2-(SLR_x2)-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>item e: simple linear regression of <code>Y</code> onto <code>X2</code> (SLR_x2)</a></span><ul class="toc-item"><li><span><a href="#Hypothesis-checking" data-toc-modified-id="Hypothesis-checking-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Hypothesis checking</a></span><ul class="toc-item"><li><span><a href="#$H_0\,-:\,\,-\beta_i-=-0$" data-toc-modified-id="$H_0\,-:\,\,-\beta_i-=-0$-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>$H_0\, :\,\, \beta_i = 0$</a></span></li><li><span><a href="#$H_0\,-:\,\,-\beta_i-=-\beta_i^{true}$" data-toc-modified-id="$H_0\,-:\,\,-\beta_i-=-\beta_i^{true}$-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>$H_0\, :\,\, \beta_i = \beta_i^{true}$</a></span></li></ul></li><li><span><a href="#Conclusions:" data-toc-modified-id="Conclusions:-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Conclusions:</a></span></li></ul></li><li><span><a href="#item-f:-how-MLR,-SLR_x1-and-SLR_x2-contradict-each-other" data-toc-modified-id="item-f:-how-MLR,-SLR_x1-and-SLR_x2-contradict-each-other-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>item f: how <code>MLR</code>, <code>SLR_x1</code> and <code>SLR_x2</code> contradict each other</a></span><ul class="toc-item"><li><span><a href="#Conclusions:" data-toc-modified-id="Conclusions:-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Conclusions:</a></span></li></ul></li><li><span><a href="#item-g:-influence-of-one-added-sample" data-toc-modified-id="item-g:-influence-of-one-added-sample-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>item g: influence of one added sample</a></span><ul class="toc-item"><li><span><a href="#Conclusions:" data-toc-modified-id="Conclusions:-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Conclusions:</a></span></li></ul></li><li><span><a href="#<<<-END-OF-DOCUMENT->>>" data-toc-modified-id="<<<-END-OF-DOCUMENT->>>-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>&lt;&lt;&lt; END OF DOCUMENT &gt;&gt;&gt;</a></span></li></ul></div>

# %% [markdown]
# # Text of exercise 14 chapter 3 ISLRv2 book
#
# This problem focuses on the collinearity problem.
#
# (a) Perform the following commands in R:
# * `set.seed (1)`
# * `x1 <- runif (100)`
# * `x2 <- 0.5 * x1 + rnorm (100) / 10`
# * `y <- 2 + 2 * x1 + 0.3 * x2 + rnorm (100)`
#
# The last line corresponds to creating a linear model in which y is a function of `x1` and `x2`. Write out the form of the linear model. What are the regression coefficients?
#
# (b) What is the correlation between `x1` and `x2`? Create a scatterplot displaying the relationship between the variables.
#
# (c) Using this data, fit a least squares regression to predict y using `x1` and `x2`. Describe the results obtained. What are $\hat\beta_0$, $\hat\beta_1$, and $\hat\beta_2$ ? How do these relate to the true $\beta_0$, $\beta_1$, and $\beta_2$? Can you reject the null hypothesis $H_0\, :\,\, \beta_1 = 0$ ? How about the null hypothesis $H_0\, :\,\, \beta_2 = 0$ ?
#
# (d) Now fit a least squares regression to predict `y` using only `x1`.  Comment on your results. Can you reject the null hypothesis $H_0\, :\,\, \beta_1 = 0$?
#
# (e) Now fit a least squares regression to predict `y` using only `x2`. Comment on your results. Can you reject the null hypothesis $H_0\, :\,\, \beta_1 = 0$ ?
#
# (f) Do the results obtained in (c) – (e) contradict each other? Explain your answer.
#
# (g) Now suppose we obtain one additional observation, which was unfortunately mismeasured.
# * `x1 <- c(x1 , 0.1)`
# * `x2 <- c(x2 , 0.8)`
# * `y <- c(y, 6)`
#
# Re-fit the linear models from (c) to (e) using this new data. What effect does this new observation have on the each of the models? In each model, is this observation an outlier? A high-leverage point? Both? Explain your answers.
#
# \*) **ISLRv2** stands for: **An Introduction to Statistical Learning book by Gareth James, Daniela Witten, Trevor Hastie, Robert Tibshirani**

# %%
import datetime as dt
start_run = dt.datetime.now()

import math
import pandas as pd
import numpy as np
import scipy.stats as statmath 
from sklearn import linear_model
#from sklearn.metrics import mean_squared_error, r2_score

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Functions for used statistical formulas

# %%
def p_value(t_stat, len_df):
    return statmath.t.sf(abs(t_stat), len_df)*2

# %% [markdown]
# # items a: data generation

# %%
n_sampling = 100                                             # sampling size paramer for what-if-analysis
rng = np.random.default_rng()                                # creating Numpy-generator object
X1 = rng.uniform(size=n_sampling)                            # X1-vector with uniform-distribution over [0;1]
X2 = X1 / 2 + rng.standard_normal(size=n_sampling) / 10      # X2-vector with stochastized collinearity to X1
Y = 2 + 2*X1 + 0.3*X2 + rng.standard_normal(size=n_sampling) # Y-vector, with true nature of f(x): y = 2+2*x1+0.3*x2


df_YontoX = pd.DataFrame(
    [X1,X2,Y],
    index=['X1','X2','Y']
).T

df_YontoX.head()
# Out:
#          X1        X2         Y
# 0  0.583365  0.301352  4.073145
# 1  0.519993  0.290845  2.044209
# 2  0.646684  0.347340  1.234277
# 3  0.299857  0.246434  1.391868
# 4  0.789027  0.119570  3.548916

# %% [markdown]
# ## Conclusions:
# 1. Generated data correspond to the linear model
#
# $$ f(x)\, :\,\, y = 2 + 2x_1 + 0.3x_2 $$
#
# 2. The regression coefficients of this model are the true values behind them as:
#
# $$\begin{eqnarray}
# \beta_0 &=& 2 &; \\
# \beta_1 &=& 2 &; \\
# \beta_2 &=& 0.3 &. \\
# \end{eqnarray}$$
#
# # item b: correlation and plotting of data

# %%
df_YontoX[['X1','X2']].corr()
# Out:
#           X1        X2
# X1  1.000000  0.800418
# X2  0.800418  1.000000

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(1,2,1)
ax2 = plt.subplot(1,2,2)


sns.histplot(data=df_YontoX, x='X1', stat='count', bins=[-0.5+i/10 for i in range(21)], 
             element='step', kde=False, color='blue', alpha=0.3, ax=ax1)
sns.histplot(data=df_YontoX, x='X2', stat='count', bins=[-0.5+i/10 for i in range(21)], 
             element='step', kde=False, color='red', alpha=0.3, ax=ax1)

ax1.axvline(x=df_YontoX['X1'].mean(), color='blue', label='mean of X1 = '+str(round(df_YontoX['X1'].mean(),4)))
ax1.axvline(x=df_YontoX['X2'].mean(), color='red', label='mean of X2 = '+str(round(df_YontoX['X2'].mean(),4)))
ax1.axvline(x=0.5, color='black', label='math exp of X1 = 0.5')
ax1.axvline(x=0.25, color='black', label='math exp of X2 = 0.25')

ax1.set_xlabel('value')
ax1.set_ylabel("N of parameter's samples per 0.1 step of value")
ax1.set_xticks([-0.5+i/10 for i in range(21)])
ax1.set_xlim(-0.5,1.5)
ax1.legend()
ax1.grid()

sns.scatterplot(data=df_YontoX, x='X1', y='X2', ax=ax2)
ax2.plot([0,1], [0,0.5], color='green', label='true f(x1): x2 = x1 / 2')

ax2.axvline(x=0, color='black')
ax2.axhline(y=0, color='black')

ax2.set_xlim(-0.5,1.5)
ax2.set_ylim(-0.5,1)
ax2.legend()
ax2.grid()

print('\n', ' '*40, 'VISUALIZATION OF COLLINEARITY BETWEEN X1 AND X2:')
plt.show()
# Out:
#                                           VISUALIZATION OF COLLINEARITY BETWEEN X1 AND X2:

# %% [markdown]
# ## Conclusions:

# %%
print('RSS for collinearity between X1 and X2 makes', df_YontoX[['X1','X2']].corr().iloc[0,1]**2)
# Out:
# RSS for collinearity between X1 and X2 makes 0.6406696793294645

# %% [markdown]
# # item c: multiple linear regression of `Y` onto `X` (MLR):

# %%
X = np.array(df_YontoX.drop(columns='Y'))

MLR_model_obj_YontoX = linear_model.LinearRegression()   # creating Sklearn-object for MLR-model
MLR_model_obj_YontoX.fit(X,Y)                            # training MLR-model on the generated dataset

# let's start building a summary table for the results for easy comparisons:

params_tbl = pd.DataFrame(index=['R2_score','intercept','coef_x1','coef_x2'])
params_tbl['true_f(x)'] = [1.0,2.0,2.0,0.3]

# adding model fitting results to it:

params_tbl['smpl_MLR'] = [
    MLR_model_obj_YontoX.score(X,Y),
    MLR_model_obj_YontoX.intercept_,
    MLR_model_obj_YontoX.coef_[0],
    MLR_model_obj_YontoX.coef_[1],
]

params_tbl                            #show table
# Out:
#            true_f(x)  smpl_MLR
# R2_score         1.0  0.409820
# intercept        2.0  1.720190
# coef_x1          2.0  2.342374
# coef_x2          0.3  0.881599

# %% [markdown]
# well, already the $ \hat\beta_1 \,\mbox{and}\, \hat\beta_2 $ looks very disgusting as compared to $ \beta_1 \,\mbox{and}\, \beta_2 $ !
#
# Let's estimate their `std` and $ H_0 \, :\,\, \beta_i = 0 $ `t-statistics` and `p-values`.  As soon as our library function does not generate it as model parameters (unlike in R) we need either to make bootstrapping, or in our case (as the data are generated by us) we can simply repeat the data generation and model fitting for each new sample to collect their statistics directly:

# %%
bootstrap_df = pd.DataFrame(columns=['R2_score','intercept','coef_x1','coef_x2'])

MLR_model_obj_YontoX_bs = linear_model.LinearRegression()   # creating different Sklearn-object for MLR-model

for i in range(n_sampling):
    
    X1_bs = rng.uniform(size=n_sampling)                            
    X2_bs = X1_bs / 2 + rng.standard_normal(size=n_sampling) / 10   
    Y_bs = 2 + 2*X1_bs + 0.3*X2_bs + rng.standard_normal(size=n_sampling) 

    df_YontoX_bs = pd.DataFrame(
        [X1_bs,X2_bs,Y_bs],
        index=['X1','X2','Y']
    ).T
    X_bs = np.array(df_YontoX_bs.drop(columns='Y'))
    
    MLR_model_obj_YontoX_bs.fit(X_bs,Y_bs)    
    
    bootstrap_df.loc[i] = [
        MLR_model_obj_YontoX_bs.score(X_bs,Y_bs),
        MLR_model_obj_YontoX_bs.intercept_,
        MLR_model_obj_YontoX_bs.coef_[0],
        MLR_model_obj_YontoX_bs.coef_[1]
    ]

bootstrap_df.describe().drop(index=['25%','50%','75%'])
# Out:
#          R2_score   intercept     coef_x1     coef_x2
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.282780    2.017043    1.918293    0.366669
# std      0.067439    0.221026    0.600341    0.911986
# min      0.138782    1.354633    0.223980   -1.840686
# max      0.452303    2.550738    3.236334    2.378428

# %% [markdown]
# let's add into parameters comparisons table

# %%
params_tbl = params_tbl.join(bootstrap_df.describe().T[['std','mean']].rename(columns={
    'std':'std_MLR',
    'mean':'mean_MLR'
}))

params_tbl['L_conf_MLR'] = params_tbl['mean_MLR'] - params_tbl['std_MLR']*2/math.sqrt(n_sampling)
params_tbl['R_conf_MLR'] = params_tbl['mean_MLR'] + params_tbl['std_MLR']*2/math.sqrt(n_sampling)

params_tbl
# Out:
#            true_f(x)  smpl_MLR   std_MLR  mean_MLR  L_conf_MLR  R_conf_MLR
# R2_score         1.0  0.409820  0.067439  0.282780    0.269292    0.296267
# intercept        2.0  1.720190  0.221026  2.017043    1.972838    2.061249
# coef_x1          2.0  2.342374  0.600341  1.918293    1.798224    2.038361
# coef_x2          0.3  0.881599  0.911986  0.366669    0.184272    0.549066

# %% [markdown]
# ## Hypothesis checking
# ### $H_0\, :\,\, \beta_i = 0$

# %%
df_tmp = params_tbl.drop(index='R2_score')
df_tmp['t-stat'] = df_tmp['smpl_MLR'] / df_tmp['std_MLR']
df_tmp['p-value'] = df_tmp['t-stat'].apply(lambda t_stat: p_value(t_stat, n_sampling))

show_MLR = df_tmp
round(show_MLR,5)
# Out:
#            true_f(x)  smpl_MLR  std_MLR  mean_MLR  L_conf_MLR  R_conf_MLR  \
# intercept        2.0   1.72019  0.22103   2.01704     1.97284     2.06125
# coef_x1          2.0   2.34237  0.60034   1.91829     1.79822     2.03836
# coef_x2          0.3   0.88160  0.91199   0.36667     0.18427     0.54907
#
#             t-stat  p-value
# intercept  7.78276  0.00000
# coef_x1    3.90174  0.00017
# coef_x2    0.96668  0.33604

# %% [markdown]
# ### $H_0\, :\,\, \beta_i = \beta_i^{true}$

# %%
df_tmp = params_tbl.drop(index='R2_score')
df_tmp['t-stat'] = (df_tmp['smpl_MLR'] - df_tmp['true_f(x)'] ) / df_tmp['std_MLR']
df_tmp['p-value'] = df_tmp['t-stat'].apply(lambda t_stat: p_value(t_stat, n_sampling))

def check_f(df):
    if df['L_conf_MLR'] <= df['true_f(x)'] <= df['R_conf_MLR']:
        return True
    else:
        return False

df_tmp['if true Beta fits conf.int. for mean sampling?'] = df_tmp.apply(check_f,axis=1)

show_MLR_bis = df_tmp
round(show_MLR_bis,5)
# Out:
#            true_f(x)  smpl_MLR  std_MLR  mean_MLR  L_conf_MLR  R_conf_MLR  \
# intercept        2.0   1.72019  0.22103   2.01704     1.97284     2.06125
# coef_x1          2.0   2.34237  0.60034   1.91829     1.79822     2.03836
# coef_x2          0.3   0.88160  0.91199   0.36667     0.18427     0.54907
#
#             t-stat  p-value  if true Beta fits conf.int. for mean sampling?
# intercept -1.26596  0.20847                                            True
# coef_x1    0.57030  0.56975                                            True
# coef_x2    0.63773  0.52511                                            True

# %% [markdown]
# ## Conclusions:
# 1. The $H_0\, :\,\, \beta_i = 0$ can be rejected only for $ \beta_0\, \mbox{and}\, \beta_1 $, but not for $\beta_2$ .
# 2. The $H_0\, :\,\, \beta_i = \beta_i^{true}$ cannot be rejected for all $\beta_i$, yet the confidence interval for mean sampling does fit the $\beta_i^{true}$ .

# %% [markdown]
# # item d: simple linear regression of `Y` onto `X1` (SLR_x1)

# %%
SLR_model_obj_YontoX1 = linear_model.LinearRegression()   
SLR_model_obj_YontoX1.fit(X1.reshape(-1, 1),Y)            

params_tbl['smpl_SLR_x1'] = [
    SLR_model_obj_YontoX1.score(X1.reshape(-1, 1),Y),
    SLR_model_obj_YontoX1.intercept_,
    SLR_model_obj_YontoX1.coef_[0],
    None,
]          

bootstrap_df = pd.DataFrame(columns=['R2_score','intercept','coef_x1','coef_x2'])

SLR_model_obj_YontoX1_bs = linear_model.LinearRegression()   

for i in range(n_sampling):
    
    X1_bs = rng.uniform(size=n_sampling)                            
    X2_bs = X1_bs / 2 + rng.standard_normal(size=n_sampling) / 10   
    Y_bs = 2 + 2*X1_bs + 0.3*X2_bs + rng.standard_normal(size=n_sampling) 

    SLR_model_obj_YontoX1_bs.fit(X1_bs.reshape(-1, 1),Y_bs)    
    
    bootstrap_df.loc[i] = [
        SLR_model_obj_YontoX1_bs.score(X1_bs.reshape(-1, 1),Y_bs),
        SLR_model_obj_YontoX1_bs.intercept_,
        SLR_model_obj_YontoX1_bs.coef_[0],
        None
    ]

params_tbl = params_tbl.join(bootstrap_df.describe().T[['std','mean']].rename(columns={
    'std':'std_SLR_x1',
    'mean':'mean_SLR_x1'
}))

params_tbl[['true_f(x)','smpl_MLR','smpl_SLR_x1','std_MLR','std_SLR_x1','mean_MLR','mean_SLR_x1']]
# Out:
#            true_f(x)  smpl_MLR  smpl_SLR_x1   std_MLR  std_SLR_x1  mean_MLR  \
# R2_score         1.0  0.409820     0.405355  0.067439    0.071527  0.282780
# intercept        2.0  1.720190     1.762490  0.221026    0.186593  2.017043
# coef_x1          2.0  2.342374     2.724147  0.600341    0.324592  1.918293
# coef_x2          0.3  0.881599          NaN  0.911986         NaN  0.366669
#
#            mean_SLR_x1
# R2_score      0.286466
# intercept     1.992754
# coef_x1       2.184992
# coef_x2            NaN

# %% [markdown]
# ## Hypothesis checking
#
# ### $H_0\, :\,\, \beta_i = 0$

# %%
df_tmp = params_tbl.drop(index=['R2_score','coef_x2'])
df_tmp['t-stat'] = df_tmp['smpl_SLR_x1'] / df_tmp['std_SLR_x1']
df_tmp['p-value'] = df_tmp['t-stat'].apply(lambda t_stat: p_value(t_stat, n_sampling))

show_SLR_x1 = df_tmp

print('\nfor Y regression onto X1 and X2:', end=' ')
display(show_MLR[['t-stat','p-value']].iloc[[0,1]])
print('\nfor Y regression onto X1 only:', end=' ')
display(show_SLR_x1[['t-stat','p-value']])
# Out:
# for Y regression onto X1 and X2:
#              t-stat       p-value
# intercept  7.782762  6.643182e-12
# coef_x1    3.901739  1.732908e-04
# for Y regression onto X1 only:
#              t-stat       p-value
# intercept  9.445620  1.626056e-15
# coef_x1    8.392523  3.228646e-13

# %% [markdown]
# ### $H_0\, :\,\, \beta_i = \beta_i^{true}$

# %%
df_tmp = params_tbl.drop(index=['R2_score','coef_x2'])
df_tmp['t-stat'] = ( df_tmp['smpl_SLR_x1'] - df_tmp['true_f(x)'] ) / df_tmp['std_SLR_x1']
df_tmp['p-value'] = df_tmp['t-stat'].apply(lambda t_stat: p_value(t_stat, n_sampling))

show_SLR_x1_bis = df_tmp

print('\nfor Y regression onto X1 and X2:', end=' ')
display(show_MLR_bis[['t-stat','p-value']].iloc[[0,1]])
print('\nfor Y regression onto X1 only:', end=' ')
display(show_SLR_x1_bis[['t-stat','p-value']])
# Out:
# for Y regression onto X1 and X2:
#              t-stat   p-value
# intercept -1.265964  0.208467
# coef_x1    0.570300  0.569754
# for Y regression onto X1 only:
#              t-stat   p-value
# intercept -1.272876  0.206013
# coef_x1    2.230944  0.027919

# %% [markdown]
# ## Conclusions:
# 1. For $\beta_1$ `std_SLR_x1` was almost twice less than `std_MLR`
# 2. Naturally for the hypothesis $ H_0\, :\,\, \beta_1 = 0 $ the `t-statistics` gets twice
# 3. And yet somehow for the hypothesis $ H_0\, :\,\, \beta_1 = 2 $ the `t-statistics` is not very impressive - why?
# 4. This can be explained like that:
#  * when we drop X2, because of collenearity we must use as the true $ \beta_1^{true}\, =\, 2 + 0.3*0.5 - \omicron_{st} \, =\, 2.15 - \omicron_{st} $ , where $\omicron_{st}$ is actually the *small* influence of stochastisity introduced in X2, as investigated in earlier exercises to this chapter.
#
# Let's check the last one:

# %%
df_tmp = params_tbl.drop(index=['R2_score','coef_x2','intercept'])
df_tmp['t-stat'] = ( df_tmp['smpl_SLR_x1'] - 2.15 ) / df_tmp['std_SLR_x1']
df_tmp['p-value'] = df_tmp['t-stat'].apply(lambda t_stat: p_value(t_stat, n_sampling))

print('\nfor Ho: beta_1=2,15', end=' ')
df_tmp[['t-stat','p-value']]
# Out:
# for Ho: beta_1=2,15
#            t-stat   p-value
# coef_x1  1.768826  0.079972

# %% [markdown]
# not enough good, but if we use mean value instead of sample value:

# %%
df_tmp = params_tbl.drop(index=['R2_score','coef_x2','intercept'])
df_tmp['t-stat'] = ( df_tmp['mean_SLR_x1'] - 2.15 ) / df_tmp['std_SLR_x1']
df_tmp['p-value'] = df_tmp['t-stat'].apply(lambda t_stat: p_value(t_stat, n_sampling))

print('\nfor Ho: beta_1=2,15', end=' ')
df_tmp[['t-stat','p-value']]
# Out:
# for Ho: beta_1=2,15
#            t-stat   p-value
# coef_x1  0.107803  0.914368

# %% [markdown]
# now good - the mean $\beta_1$ is very close to 2.15 !

# %% [markdown]
# # item e: simple linear regression of `Y` onto `X2` (SLR_x2)

# %%
SLR_model_obj_YontoX2 = linear_model.LinearRegression()   
SLR_model_obj_YontoX2.fit(X2.reshape(-1, 1),Y)            

params_tbl['smpl_SLR_x2'] = [
    SLR_model_obj_YontoX2.score(X2.reshape(-1, 1),Y),
    SLR_model_obj_YontoX2.intercept_,
    None,
    SLR_model_obj_YontoX2.coef_[0],
]          

bootstrap_df = pd.DataFrame(columns=['R2_score','intercept','coef_x1','coef_x2'])

SLR_model_obj_YontoX2_bs = linear_model.LinearRegression()   

for i in range(n_sampling):
    
    X1_bs = rng.uniform(size=n_sampling)                            
    X2_bs = X1_bs / 2 + rng.standard_normal(size=n_sampling) / 10   
    Y_bs = 2 + 2*X1_bs + 0.3*X2_bs + rng.standard_normal(size=n_sampling) 

    SLR_model_obj_YontoX2_bs.fit(X2_bs.reshape(-1, 1),Y_bs)    
    
    bootstrap_df.loc[i] = [
        SLR_model_obj_YontoX2_bs.score(X2_bs.reshape(-1, 1),Y_bs),
        SLR_model_obj_YontoX2_bs.intercept_,
        None,
        SLR_model_obj_YontoX2_bs.coef_[0],
    ]

params_tbl = params_tbl.join(bootstrap_df.describe().T[['std','mean']].rename(columns={
    'std':'std_SLR_x2',
    'mean':'mean_SLR_x2'
}))

params_tbl[['true_f(x)','smpl_MLR','smpl_SLR_x1','smpl_SLR_x2','std_MLR','std_SLR_x1','std_SLR_x2',
            'mean_MLR','mean_SLR_x1','mean_SLR_x2']]
# Out:
#            true_f(x)  smpl_MLR  smpl_SLR_x1  smpl_SLR_x2   std_MLR  \
# R2_score         1.0  0.409820     0.405355     0.302129  0.067439
# intercept        2.0  1.720190     1.762490     1.979588  0.221026
# coef_x1          2.0  2.342374     2.724147          NaN  0.600341
# coef_x2          0.3  0.881599          NaN     4.347026  0.911986
#
#            std_SLR_x1  std_SLR_x2  mean_MLR  mean_SLR_x1  mean_SLR_x2
# R2_score     0.071527    0.067983  0.282780     0.286466     0.203208
# intercept    0.186593    0.184983  2.017043     1.992754     2.303253
# coef_x1      0.324592         NaN  1.918293     2.184992          NaN
# coef_x2           NaN    0.626525  0.366669          NaN     3.044537

# %% [markdown]
# ## Hypothesis checking
#
# ### $H_0\, :\,\, \beta_i = 0$

# %%
df_tmp = params_tbl.drop(index=['R2_score','coef_x1'])
df_tmp['t-stat'] = df_tmp['smpl_SLR_x2'] / df_tmp['std_SLR_x2']
df_tmp['p-value'] = df_tmp['t-stat'].apply(lambda t_stat: p_value(t_stat, n_sampling))

show_SLR_x2 = df_tmp

print('\nfor Y regression onto X1 and X2:', end=' ')
display(show_MLR[['t-stat','p-value']].iloc[[0,2]])
print('\nfor Y regression onto X2 only:', end=' ')
display(show_SLR_x2[['t-stat','p-value']])
# Out:
# for Y regression onto X1 and X2:
#              t-stat       p-value
# intercept  7.782762  6.643182e-12
# coef_x2    0.966680  3.360359e-01
# for Y regression onto X2 only:
#               t-stat       p-value
# intercept  10.701448  2.884118e-18
# coef_x2     6.938310  4.007351e-10

# %% [markdown]
# ### $H_0\, :\,\, \beta_i = \beta_i^{true}$

# %%
df_tmp = params_tbl.drop(index=['R2_score','coef_x1'])
df_tmp['t-stat'] = ( df_tmp['smpl_SLR_x2'] - df_tmp['true_f(x)'] ) / df_tmp['std_SLR_x2']
df_tmp['p-value'] = df_tmp['t-stat'].apply(lambda t_stat: p_value(t_stat, n_sampling))

show_SLR_x2_bis = df_tmp

print('\nfor Y regression onto X1 and X2:', end=' ')
display(show_MLR_bis[['t-stat','p-value']].iloc[[0,2]])
print('\nfor Y regression onto X1 only:', end=' ')
display(show_SLR_x2_bis[['t-stat','p-value']])
# Out:
# for Y regression onto X1 and X2:
#              t-stat   p-value
# intercept -1.265964  0.208467
# coef_x2    0.637728  0.525108
# for Y regression onto X1 only:
#              t-stat       p-value
# intercept -0.110346  9.123560e-01
# coef_x2    6.459478  3.840635e-09

# %% [markdown]
# ## Conclusions:
# 1. For $\beta_2$ `std_SLR_x2` was more than twice less than `std_MLR`.
# 2. Naturally for the hypothesis $ H_0\, :\,\, \beta_2 = 0 $ the `t-statistics` gains a lot.
# 3. As well as for the hypothesis $ H_0\, :\,\, \beta_2 = 0.3 $.
# 4. So in both case the $H_0$ can be rejected
# 5. This can be explained like that:
#  * when we drop X1, because of collenearity we must use as the true $ \beta_1^{true}\, =\, 0.3+ 2*2 - O_{st} \, =\, 4.3 - O_{st} $ , where $O_{st}$ is actually the *huge* influence of stochastisity introduced in X2, as investigated in earlier exercises to this chapter.
# 6. As we do not know $O_{st}$ we cannot check the last one this time exactly, but we can use mean $\beta_2 = 3.056$ as a good approximation of $\beta_1^{true}$.
# 7. Thus we can estimate the stochastic influence on $\beta_2$ in Y regression on X2 only as 4.3 - 3.1 = 1.2 - the reasons were investigated in earlier exercises of this chapter - it is because X2 has stochastic term so the slope is heavily pulled down from 4.3 to 3.1.

# %% [markdown]
# # item f: how `MLR`, `SLR_x1` and `SLR_x2` contradict each other

# %%
params_tbl['L_conf_SLR_x1'] = params_tbl['mean_SLR_x1'] - params_tbl['std_SLR_x1']*2/math.sqrt(n_sampling)
params_tbl['R_conf_SLR_x1'] = params_tbl['mean_SLR_x1'] + params_tbl['std_SLR_x1']*2/math.sqrt(n_sampling)

params_tbl['L_conf_SLR_x2'] = params_tbl['mean_SLR_x2'] - params_tbl['std_SLR_x2']*2/math.sqrt(n_sampling)
params_tbl['R_conf_SLR_x2'] = params_tbl['mean_SLR_x2'] + params_tbl['std_SLR_x2']*2/math.sqrt(n_sampling)

# %%
print('\n',' '*20, 'THE CONFIDENCE INTERVALS FOR MEAN BETAS IN', n_sampling, 'SAMPLING AND MODEL REFITTING:')
params_tbl[['true_f(x)','L_conf_MLR','mean_MLR','R_conf_MLR',
            'L_conf_SLR_x1','mean_SLR_x1','R_conf_SLR_x1',
            'L_conf_SLR_x2','mean_SLR_x2','R_conf_SLR_x2']].drop(index='R2_score').reset_index(drop=True)
# Out:
#                       THE CONFIDENCE INTERVALS FOR MEAN BETAS IN 100 SAMPLING AND MODEL REFITTING:
#    true_f(x)  L_conf_MLR  mean_MLR  R_conf_MLR  L_conf_SLR_x1  mean_SLR_x1  \
# 0        2.0    1.972838  2.017043    2.061249       1.955435     1.992754
# 1        2.0    1.798224  1.918293    2.038361       2.120074     2.184992
# 2        0.3    0.184272  0.366669    0.549066            NaN          NaN
#
#    R_conf_SLR_x1  L_conf_SLR_x2  mean_SLR_x2  R_conf_SLR_x2
# 0       2.030072       2.266256     2.303253       2.340249
# 1       2.249910            NaN          NaN            NaN
# 2            NaN       2.919232     3.044537       3.169842

# %% [markdown]
# ## Conclusions:
# 1. The results of mean sampling for all betas gives us the confidence intervals match to the true betas:
#  * true values for all $\beta_i$ are fitting confidence interval for MLR betas,
#  * true value for $\beta_1$ is outside confidence interval for SLR onto x1,
#  * true values for all $\beta_i$ are outside confidence interval for SLR onto x2.
# 2. There is no error in this, because whenever we drop one of the X, we have to recalculate true $\beta_1$ for the resting one the following way:
#  * for x1 the $\beta_{slope} = 2.15 - \omicron_{st}$ ,
#  * for x2 the $\beta_{slope} = 4.3 - O_{st}$ .
# 3. Because the share of the dropped X in Y is fit as the change of $\beta_{slope}$ corresponding to resting X.
# 4. The regression betas are less than true betas because of added stochastisity of X as was investigated in details in previous exercises to this chapter.

# %% [markdown]
# # item g: influence of one added sample

# %%
X1 = np.array(list(X1)+[0.1])
X2 = np.array(list(X2)+[0.8])
Y  = np.array(list(Y) +[6.0])

# %%
df_YontoX = pd.DataFrame(
    [X1,X2,Y],
    index=['X1','X2','Y']
).T

# %%
params_tbl_100 = params_tbl.copy(deep=True) # saving previous results to avoid code modifications below

# %%
# simply copy-pasting all necessarty code from (a) - (f) and adding only this to bootstrapping code 3-times below:
#    X1_bs = np.array(list(X1_bs)+[0.1])
#    X2_bs = np.array(list(X2_bs)+[0.8])
#    Y_bs  = np.array(list(Y_bs) +[6.0])


X = np.array(df_YontoX.drop(columns='Y'))

MLR_model_obj_YontoX = linear_model.LinearRegression()   # creating Sklearn-object for MLR-model
MLR_model_obj_YontoX.fit(X,Y)                            # training MLR-model on the generated dataset

# let's start building a summary table for the results for easy comparisons:

params_tbl = pd.DataFrame(index=['R2_score','intercept','coef_x1','coef_x2'])
params_tbl['true_f(x)'] = [1.0,2.0,2.0,0.3]

# adding model fitting results to it:

params_tbl['smpl_MLR'] = [
    MLR_model_obj_YontoX.score(X,Y),
    MLR_model_obj_YontoX.intercept_,
    MLR_model_obj_YontoX.coef_[0],
    MLR_model_obj_YontoX.coef_[1],
]

bootstrap_df = pd.DataFrame(columns=['R2_score','intercept','coef_x1','coef_x2'])

MLR_model_obj_YontoX_bs = linear_model.LinearRegression()   # creating different Sklearn-object for MLR-model

for i in range(n_sampling):
    
    X1_bs = rng.uniform(size=n_sampling)                            
    X2_bs = X1_bs / 2 + rng.standard_normal(size=n_sampling) / 10   
    Y_bs = 2 + 2*X1_bs + 0.3*X2_bs + rng.standard_normal(size=n_sampling) 

    X1_bs = np.array(list(X1_bs)+[0.1])
    X2_bs = np.array(list(X2_bs)+[0.8])
    Y_bs  = np.array(list(Y_bs) +[6.0])

    df_YontoX_bs = pd.DataFrame(
        [X1_bs,X2_bs,Y_bs],
        index=['X1','X2','Y']
    ).T
    X_bs = np.array(df_YontoX_bs.drop(columns='Y'))
    
    MLR_model_obj_YontoX_bs.fit(X_bs,Y_bs)    
    
    bootstrap_df.loc[i] = [
        MLR_model_obj_YontoX_bs.score(X_bs,Y_bs),
        MLR_model_obj_YontoX_bs.intercept_,
        MLR_model_obj_YontoX_bs.coef_[0],
        MLR_model_obj_YontoX_bs.coef_[1]
    ]

params_tbl = params_tbl.join(bootstrap_df.describe().T[['std','mean']].rename(columns={
    'std':'std_MLR',
    'mean':'mean_MLR'
}))

params_tbl['L_conf_MLR'] = params_tbl['mean_MLR'] - params_tbl['std_MLR']*2/math.sqrt(n_sampling)
params_tbl['R_conf_MLR'] = params_tbl['mean_MLR'] + params_tbl['std_MLR']*2/math.sqrt(n_sampling)

SLR_model_obj_YontoX1 = linear_model.LinearRegression()   
SLR_model_obj_YontoX1.fit(X1.reshape(-1, 1),Y)            

params_tbl['smpl_SLR_x1'] = [
    SLR_model_obj_YontoX1.score(X1.reshape(-1, 1),Y),
    SLR_model_obj_YontoX1.intercept_,
    SLR_model_obj_YontoX1.coef_[0],
    None,
]          

bootstrap_df = pd.DataFrame(columns=['R2_score','intercept','coef_x1','coef_x2'])

SLR_model_obj_YontoX1_bs = linear_model.LinearRegression()   

for i in range(n_sampling):
    
    X1_bs = rng.uniform(size=n_sampling)                            
    X2_bs = X1_bs / 2 + rng.standard_normal(size=n_sampling) / 10   
    Y_bs = 2 + 2*X1_bs + 0.3*X2_bs + rng.standard_normal(size=n_sampling) 

    X1_bs = np.array(list(X1_bs)+[0.1])
    X2_bs = np.array(list(X2_bs)+[0.8])
    Y_bs  = np.array(list(Y_bs) +[6.0])

    SLR_model_obj_YontoX1_bs.fit(X1_bs.reshape(-1, 1),Y_bs)    
    
    bootstrap_df.loc[i] = [
        SLR_model_obj_YontoX1_bs.score(X1_bs.reshape(-1, 1),Y_bs),
        SLR_model_obj_YontoX1_bs.intercept_,
        SLR_model_obj_YontoX1_bs.coef_[0],
        None
    ]

params_tbl = params_tbl.join(bootstrap_df.describe().T[['std','mean']].rename(columns={
    'std':'std_SLR_x1',
    'mean':'mean_SLR_x1'
}))

SLR_model_obj_YontoX2 = linear_model.LinearRegression()   
SLR_model_obj_YontoX2.fit(X2.reshape(-1, 1),Y)            

params_tbl['smpl_SLR_x2'] = [
    SLR_model_obj_YontoX2.score(X2.reshape(-1, 1),Y),
    SLR_model_obj_YontoX2.intercept_,
    None,
    SLR_model_obj_YontoX2.coef_[0],
]          

bootstrap_df = pd.DataFrame(columns=['R2_score','intercept','coef_x1','coef_x2'])

SLR_model_obj_YontoX2_bs = linear_model.LinearRegression()   

for i in range(n_sampling):
    
    X1_bs = rng.uniform(size=n_sampling)                            
    X2_bs = X1_bs / 2 + rng.standard_normal(size=n_sampling) / 10   
    Y_bs = 2 + 2*X1_bs + 0.3*X2_bs + rng.standard_normal(size=n_sampling) 

    X1_bs = np.array(list(X1_bs)+[0.1])
    X2_bs = np.array(list(X2_bs)+[0.8])
    Y_bs  = np.array(list(Y_bs) +[6.0])

    SLR_model_obj_YontoX2_bs.fit(X2_bs.reshape(-1, 1),Y_bs)    
    
    bootstrap_df.loc[i] = [
        SLR_model_obj_YontoX2_bs.score(X2_bs.reshape(-1, 1),Y_bs),
        SLR_model_obj_YontoX2_bs.intercept_,
        None,
        SLR_model_obj_YontoX2_bs.coef_[0],
    ]

params_tbl = params_tbl.join(bootstrap_df.describe().T[['std','mean']].rename(columns={
    'std':'std_SLR_x2',
    'mean':'mean_SLR_x2'
}))

params_tbl['L_conf_SLR_x1'] = params_tbl['mean_SLR_x1'] - params_tbl['std_SLR_x1']*2/math.sqrt(n_sampling)
params_tbl['R_conf_SLR_x1'] = params_tbl['mean_SLR_x1'] + params_tbl['std_SLR_x1']*2/math.sqrt(n_sampling)

params_tbl['L_conf_SLR_x2'] = params_tbl['mean_SLR_x2'] - params_tbl['std_SLR_x2']*2/math.sqrt(n_sampling)
params_tbl['R_conf_SLR_x2'] = params_tbl['mean_SLR_x2'] + params_tbl['std_SLR_x2']*2/math.sqrt(n_sampling)

# %%
params_tbl_101 = params_tbl.copy(deep=True)  # saving new results to compare with the old ones

params_delta_tbl = params_tbl_101 - params_tbl_100

params_rel_delta_tbl = params_delta_tbl / params_tbl_100 * 100

print('\n',' '*10, 'RELATIVE CHANGE OF THE MODELS PARAMETERS AFTER ADDING ONE NEW SAMPLE TO', n_sampling, 
      'SAMPLING (in %)')
round(params_rel_delta_tbl[[
    'true_f(x)','smpl_MLR','std_MLR','mean_MLR','smpl_SLR_x1','std_SLR_x1','mean_SLR_x1',
    'smpl_SLR_x2','std_SLR_x2','mean_SLR_x2']],1).drop(index='R2_score')
# Out:
#             RELATIVE CHANGE OF THE MODELS PARAMETERS AFTER ADDING ONE NEW SAMPLE TO 100 SAMPLING (in %)
#            true_f(x)  smpl_MLR  std_MLR  mean_MLR  smpl_SLR_x1  std_SLR_x1  \
# intercept        0.0      -0.6     -2.4       1.6          7.9         1.0
# coef_x1          0.0     -36.8    -31.6     -45.1         -7.3         4.1
# coef_x2          0.0     198.2    -29.8     451.8          NaN         NaN
#
#            mean_SLR_x1  smpl_SLR_x2  std_SLR_x2  mean_SLR_x2
# intercept          6.5         -1.3        -7.6         -1.1
# coef_x1           -8.2          NaN         NaN          NaN
# coef_x2            NaN          2.6       -19.1          6.0

# %% [markdown]
# ## Conclusions:
# 1. Repeating the run-all several times we can see always that $ \beta_1\, \mbox{and}\, \beta_2 $ in MLR-model are very unstable to adding just one outliner to the 100 correctly denerated samples - as compared to both SLR variants.
# 2. This instability is valid not only to one sample coefficients, but also to their mean values!
# 3. Therefore we can conclude, that in case of collenearity of predictors the main benefit of linear model (interpretability of coefficients) can be easily lost by only one occasional outliner added to the data set by some mistake!
# 4. But alas, in reality we cannot say which samples are following the hidden f(x) and which are irrelevant to it, **so the only way to keep interpretability of linear model is to be sure that there are no collinearity among the predictors**.
# 5. Alas the binary correlator form can help only in case dim X = 2, if dim X > 2, there could be hidden collinearity when X1 = a * X2 + b * X3.  As an idea for dim X > 2 we can put aside Y and try to predict by MLR all Xi our of X - in case the X1 = a * X2 + b * X3 is behind the data, we should get R2 for prediction of X1, X2 and X3 anomally high.
# 6. Despite unstable coefficients for MLR in case of collinearity of predictors, it does not obligatory mean that prediction of Y shall be bad - simply we can get close predictions for very different set of betas!  So only interpretability shall really suffer.

# %% [markdown]
# # <<< END OF DOCUMENT >>>

# %%
stop_run = dt.datetime.now()
print('If you see this line, then run-all-cells command has been executed successfully!')
print('Full execution time was', round((stop_run-start_run).total_seconds(),2),'seconds. ',
     'The last run-through of this Notebook was on', stop_run.date(), 'at', str(stop_run.time()).split('.')[0] )
# Out:
# If you see this line, then run-all-cells command has been executed successfully!
# Full execution time was 3.48 seconds.  The last run-through of this Notebook was on 2023-01-11 at 22:38:27
